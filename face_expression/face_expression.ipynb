# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from os import chdir
chdir('/content/drive/My Drive/huyen/face_expression')

# %%
# !unzip "/content/drive/My Drive/huyen/face_expression/FER_2013/test/surprise.zip" -d "/content/drive/My Drive/huyen/face_expression/FER_2013/test/"
# Out:
# Archive:  /content/drive/My Drive/huyen/face_expression/FER_2013/test/surprise.zip
#    creating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/surprise/
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/surprise/PrivateTest_10072988.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/surprise/PrivateTest_10089743.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/surprise/PrivateTest_104142.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/surprise/PrivateTest_10427382.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/surprise/PrivateTest_10712253.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/surprise/PrivateTest_1076980.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/surprise/PrivateTest_10775220.jpg
# ...

# %%
# !unzip "/content/drive/My Drive/huyen/face_expression/FER_2013.zip" -d "/content/drive/My Drive/huyen/face_expression/"
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/happy/PrivateTest_2764941.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/happy/PrivateTest_27678988.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/happy/PrivateTest_27778676.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/happy/PrivateTest_28122366.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/happy/PrivateTest_28576977.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/happy/PrivateTest_28785248.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/happy/PrivateTest_28872144.jpg
#   inflating: /content/drive/My Drive/huyen/face_expression/FER_2013/test/happy/PrivateTest_29012170.jpg
# ...

# %%
# !bunzip2 -d "/content/drive/My Drive/huyen/face_expression/shape_predictor_68_face_landmarks.dat.bz2"
# Out:
# bunzip2: Can't open input file /content/drive/My Drive/huyen/face_expression/shape_predictor_68_face_landmarks.dat.bz2: No such file or directory.

# %%
# !git clone https://github.com/amineHorseman/facial-expression-recognition-using-cnn.git
# Out:
# Cloning into 'facial-expression-recognition-using-cnn'...
# remote: Enumerating objects: 202, done.
# remote: Total 202 (delta 0), reused 0 (delta 0), pack-reused 202
# Receiving objects: 100% (202/202), 475.69 KiB | 8.97 MiB/s, done.
# Resolving deltas: 100% (128/128), done.

# %%
# !mv FER_2013/test/surprise/* ./FER_2013/image/

# %%
# !pip install tflearn
# Out:
# ...
#      |████████████████████████████████| 112kB 12.0MB/s
# ...
#   Created wheel for tflearn: filename=tflearn-0.5.0-cp37-none-any.whl size=127301 sha256=2503e37508d8290da47dff941314cd74ad3bd3e5050e823b0dd62c16eebdca4e
#   Stored in directory: /root/.cache/pip/wheels/31/d2/ed/fb9a0d301dd9586c11e9547120278e624227f22fd5f4baf744
# Successfully built tflearn
# ...

# %%
# !python convert_fer2013_to_images_and_landmarks.py --hog=no --hog_windows=no
# Out:
# 14 expressions
# preparing
# importing csv file
# converting set: Training...
# converting set: PublicTest...
# converting set: PrivateTest...

# %%
# !python train.py --train=yes
# Out:
# 2021-05-12 08:08:37.681726: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# loading dataset Fer2013...
# building model...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/initializations.py:110: calling UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...

# %%
# !python train.py
# Out:
# la
# PrivateTest_10086748.jpg
# PrivateTest_10767287.jpg
# PrivateTest_11123843.jpg
# PrivateTest_11164800.jpg
# PrivateTest_11262548.jpg
# PrivateTest_1129340.jpg
# PrivateTest_11752870.jpg
# PrivateTest_11775247.jpg
# PrivateTest_12091739.jpg
# PrivateTest_12201145.jpg
# PrivateTest_12208844.jpg
# PrivateTest_12810304.jpg
# PrivateTest_13422828.jpg
# PrivateTest_13501133.jpg
# PrivateTest_13654203.jpg
# PrivateTest_13684683.jpg
# PrivateTest_13726475.jpg
# PrivateTest_13762425.jpg
# PrivateTest_14408476.jpg
# PrivateTest_14704134.jpg
# PrivateTest_14728578.jpg
# PrivateTest_14785754.jpg
# PrivateTest_15353271.jpg
# PrivateTest_15444293.jpg
# PrivateTest_15583815.jpg
# PrivateTest_15728996.jpg
# PrivateTest_15847006.jpg
# PrivateTest_16117077.jpg
# PrivateTest_16463241.jpg
# PrivateTest_16611986.jpg
# PrivateTest_16736805.jpg
# PrivateTest_17013856.jpg
# PrivateTest_17852482.jpg
# PrivateTest_1791924.jpg
# PrivateTest_18154505.jpg
# PrivateTest_18187501.jpg
# ...
