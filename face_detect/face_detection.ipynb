# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from os import chdir
chdir('/content/drive/My Drive/huyen/face_detect')

# %%
# !git clone https://github.com/biubug6/Pytorch_Retinaface.git
# Out:
# fatal: destination path 'Pytorch_Retinaface' already exists and is not an empty directory.

# %%
# !mv Pytorch_Retinaface/* ./
# !rm -r Pytorch_Retinaface/

# %%
# !unzip "/content/drive/My Drive/huyen/face_detect/data.zip" -d "/content/drive/My Drive/huyen/face_detect/"
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/55--Sports_Coach_Trainer/55_Sports_Coach_Trainer_sportcoaching_55_504.jpg
#   inflating: /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/55--Sports_Coach_Trainer/55_Sports_Coach_Trainer_sportcoaching_55_507.jpg
#   inflating: /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/55--Sports_Coach_Trainer/55_Sports_Coach_Trainer_sportcoaching_55_509.jpg
#   inflating: /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/55--Sports_Coach_Trainer/55_Sports_Coach_Trainer_sportcoaching_55_518.jpg
#   inflating: /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/55--Sports_Coach_Trainer/55_Sports_Coach_Trainer_sportcoaching_55_529.jpg
# ...

# %%
# !unzip "/content/drive/My Drive/huyen/face_detect/weights-20210408T021812Z-001.zip" -d "/content/drive/My Drive/huyen/face_detect/"
# Out:
# Archive:  /content/drive/My Drive/huyen/face_detect/weights-20210408T021812Z-001.zip
#   inflating: /content/drive/My Drive/huyen/face_detect/weights/Resnet50_epoch_10.pth
#   inflating: /content/drive/My Drive/huyen/face_detect/weights/Resnet50_Final_mini.pth

# %%
# !unzip "/content/drive/My Drive/huyen/face_detect/widerface_evaluate-20210408T021909Z-001.zip" -d "/content/drive/My Drive/huyen/face_detect/"
# Out:
# Archive:  /content/drive/My Drive/huyen/face_detect/widerface_evaluate-20210408T021909Z-001.zip
#   inflating: /content/drive/My Drive/huyen/face_detect/widerface_evaluate/setup.py
#   inflating: /content/drive/My Drive/huyen/face_detect/widerface_evaluate/evaluation.py
#   inflating: /content/drive/My Drive/huyen/face_detect/widerface_evaluate/box_overlaps.pyx
#   inflating: /content/drive/My Drive/huyen/face_detect/widerface_evaluate/README.md
#   inflating: /content/drive/My Drive/huyen/face_detect/widerface_evaluate/ground_truth/wider_face_val.mat
#   inflating: /content/drive/My Drive/huyen/face_detect/widerface_evaluate/build/temp.linux-x86_64-3.7/box_overlaps.o
#   inflating: /content/drive/My Drive/huyen/face_detect/widerface_evaluate/box_overlaps.c
#   inflating: /content/drive/My Drive/huyen/face_detect/widerface_evaluate/ground_truth/wider_medium_val.mat
#   inflating: /content/drive/My Drive/huyen/face_detect/widerface_evaluate/ground_truth/wider_hard_val.mat
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0,1,2,3 python train.py --network resnet50
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/4--Dancing/4_Dancing_Dancing_4_42.jpg
# /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/4--Dancing/4_Dancing_Dancing_4_779.jpg
# /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/4--Dancing/4_Dancing_Dancing_4_835.jpg
# /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/4--Dancing/4_Dancing_Dancing_4_369.jpg
# /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/4--Dancing/4_Dancing_Dancing_4_836.jpg
# /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/4--Dancing/4_Dancing_Dancing_4_380.jpg
# /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/4--Dancing/4_Dancing_Dancing_4_455.jpg
# /content/drive/My Drive/huyen/face_detect/data/widerface/train/images/4--Dancing/4_Dancing_Dancing_4_92.jpg
# ...

# %%
# !python test_widerface.py --network resnet50
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# (1534, 1024, 3)
# im_detect: 727/3226 forward_pass_time: 0.3562s misc: 0.0578s
# (874, 1024, 3)
# im_detect: 728/3226 forward_pass_time: 0.3557s misc: 0.0578s
# (685, 1024, 3)
# im_detect: 729/3226 forward_pass_time: 0.3552s misc: 0.0578s
# (768, 1024, 3)
# im_detect: 730/3226 forward_pass_time: 0.3547s misc: 0.0578s
# (681, 1024, 3)
# im_detect: 731/3226 forward_pass_time: 0.3542s misc: 0.0578s
# (768, 1024, 3)
# im_detect: 732/3226 forward_pass_time: 0.3538s misc: 0.0577s
# (684, 1024, 3)
# im_detect: 733/3226 forward_pass_time: 0.3533s misc: 0.0577s
# (773, 1024, 3)
# im_detect: 734/3226 forward_pass_time: 0.3528s misc: 0.0577s
# (1383, 1024, 3)
# im_detect: 735/3226 forward_pass_time: 0.3526s misc: 0.0578s
# (728, 1024, 3)
# im_detect: 736/3226 forward_pass_time: 0.3522s misc: 0.0578s
# (683, 1024, 3)
# im_detect: 737/3226 forward_pass_time: 0.3517s misc: 0.0577s
# (1276, 1024, 3)
# ...

# %%
# %cd ./widerface_evaluate
# Out:
# /content/drive/MyDrive/huyen/face_detect/widerface_evaluate

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext

# %%
# !python evaluation.py
# Out:
# Reading Predictions : 100% 61/61 [00:02<00:00, 26.74it/s]
# Processing easy: 100% 61/61 [00:19<00:00,  3.17it/s]
# Processing medium: 100% 61/61 [00:19<00:00,  3.17it/s]
# Processing hard: 100% 61/61 [00:19<00:00,  3.14it/s]
# ==================== Results ====================
# Easy   Val AP: 0.9532191846419333
# Medium Val AP: 0.9426730397925361
# Hard   Val AP: 0.8591471832102207
# ...
