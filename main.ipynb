# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
from os import chdir
chdir('/content/drive/My Drive/huyen')

# %%
# !python final_main.py
# Out:
# remove prefix 'module.'
# Finished loading face detection model!
# Finished loading facial expression recognition model!
# Num of faces: 30
