# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from os import chdir
chdir('/content/drive/My Drive/huyen/darknet')

# %%
# !git clone https://github.com/pjreddie/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 5934 (delta 0), reused 1 (delta 0), pack-reused 5931
# Receiving objects: 100% (5934/5934), 6.35 MiB | 10.00 MiB/s, done.
# Resolving deltas: 100% (3925/3925), done.
# Checking out files: 100% (979/979), done.

# %%
# !mv darknet/* ./
# !rm -r darknet/
# Out:
# mv: cannot stat 'darknet/*': Not a directory
# rm: cannot remove 'darknet/': Not a directory

# %%
# !make
# Out:
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./examples/detector.c -o obj/detector.o
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN obj/captcha.o obj/lsd.o obj/super.o obj/art.o obj/tag.o obj/cifar.o obj/go.o obj/rnn.o obj/segmenter.o obj/regressor.o obj/classifier.o obj/coco.o obj/yolo.o obj/detector.o obj/nightmare.o obj/instance-segmenter.o obj/darknet.o libdarknet.a -o darknet -lm -pthread  `pkg-config --libs opencv` -lstdc++ -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -lcudnn -lstdc++  libdarknet.a

# %%
# !chmod +x darknet

# %%
!	./darknet detector train widerface.data cfg/yolov3.cfg darknet53.conv.74
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Region 94 Avg IOU: 0.841034, Class: 0.999540, Obj: 0.910624, No Obj: 0.000612, .5R: 1.000000, .75R: 1.000000,  count: 8
# Region 106 Avg IOU: 0.709972, Class: 0.999858, Obj: 0.576062, No Obj: 0.000111, .5R: 1.000000, .75R: 0.285714,  count: 14
# Region 82 Avg IOU: 0.825008, Class: 0.999943, Obj: 0.997145, No Obj: 0.000487, .5R: 1.000000, .75R: 1.000000,  count: 2
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.644424, Class: 0.999852, Obj: 0.720929, No Obj: 0.001105, .5R: 0.761194, .75R: 0.492537,  count: 134
# Region 82 Avg IOU: 0.909981, Class: 0.999835, Obj: 0.978476, No Obj: 0.000563, .5R: 1.000000, .75R: 1.000000,  count: 2
# Region 94 Avg IOU: 0.817761, Class: 0.999965, Obj: 0.914012, No Obj: 0.001548, .5R: 1.000000, .75R: 0.866667,  count: 30
# ...

# %%
! ./darknet detector valid widerface.data cfg/yolov3.cfg ./backup/yolov3.backup
# Out:
# results: Using default 'results'
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
# ...

# %%
# !python valid_transfer.py
# Out:
# filepath: ./widerface_result/0--Parade/0_Parade_marchingband_1_465.txt
# filepath: ./widerface_result/0--Parade/0_Parade_Parade_0_628.txt
# filepath: ./widerface_result/0--Parade/0_Parade_marchingband_1_765.txt
# filepath: ./widerface_result/0--Parade/0_Parade_Parade_0_194.txt
# filepath: ./widerface_result/0--Parade/0_Parade_marchingband_1_379.txt
# filepath: ./widerface_result/0--Parade/0_Parade_Parade_0_814.txt
# filepath: ./widerface_result/0--Parade/0_Parade_Parade_0_470.txt
# filepath: ./widerface_result/0--Parade/0_Parade_marchingband_1_1045.txt
# filepath: ./widerface_result/0--Parade/0_Parade_marchingband_1_556.txt
# filepath: ./widerface_result/0--Parade/0_Parade_Parade_0_829.txt
# filepath: ./widerface_result/0--Parade/0_Parade_marchingband_1_593.txt
# filepath: ./widerface_result/0--Parade/0_Parade_Parade_0_29.txt
# filepath: ./widerface_result/0--Parade/0_Parade_Parade_0_72.txt
# filepath: ./widerface_result/0--Parade/0_Parade_Parade_0_205.txt
# ...

# %%
chdir('/content/drive/My Drive/huyen/face_detect/widerface_evaluate')

# %%
# !python evaluation.py
# Out:
# Reading Predictions : 100% 61/61 [00:02<00:00, 22.44it/s]
# Processing easy: 100% 61/61 [00:19<00:00,  3.08it/s]
# Processing medium: 100% 61/61 [00:20<00:00,  3.02it/s]
# Processing hard: 100% 61/61 [00:20<00:00,  3.04it/s]
# ==================== Results ====================
# Easy   Val AP: 0.8482646977631798
# Medium Val AP: 0.8398039210978379
# Hard   Val AP: 0.7688159016814197
# ...
